# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Column names in dataset
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# <h2>About the Columns</h2>
# <ol>
#     <li>Pregnancies <br>
#     Shows the no of pregnancies the woman has had</li>
#     <li>Glucose <br>
#     Shows the amount of glucose level in miligram in blood</li>
#     <li>Blood Pressure<br>
#     Shows the pressure of blood in milimeter of the mercury level</li>
#     <li>Skin Thickness<br>
#     Shows the thickness of the skin in micron unit</li>
#     <li>Insulin<br>
#     Shows the insulin level of blood</li>
#     <li>BMI<br>
#     Shows the body mass index of the person. The BMI is calculated by height to weight ratio</li>
#     <li>DiabetesPedigreeFunction<br>
#     Shows the heridity flow of the diabetes from the parents to child</li>
#     <li>Age<br>
#     Shows the age of the person</li>
#     <li>Outcome<br>
#     Shows the reuslt whether the person is diabetic or not. 1 for diabetic , 0 for non-daibetic</li>
#
# </ol>

# %%
# Check for null values in the dataset
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # No null values in the dataset
# <h3>EDA</h3>
#
# <h2>ScatterPlot:</h2>

# %%
sns.scatterplot(x="Pregnancies", y="Outcome", data=df)

# %% [markdown]
# <strong>Women who are more than 13 weeks pregnant are at more risk to Diabetes</strong>

# %%
sns.scatterplot(x='Glucose', y='Outcome', data=df)

# %% [markdown]
# <strong>Data is almost equally distribted bwtween 55 to 200. we can say that if you have glucose level below 55, you are at no risk of diabetes</strong>

# %%
sns.scatterplot(x='BloodPressure', y='Outcome', data=df)

# %% [markdown]
# <strong>BloodPressure is alomst equally distributed between 45 to 100. If BP Exceeds 100 then there are high chances the person is diabetic.</strong>

# %%
sns.scatterplot(x='Insulin', y='Outcome', data=df)

# %% [markdown]
# <strong>Insulin is almost equally distributed between 0 to 400. Insulin greater than 420 may have a high chance of diabetes</strong>

# %%
sns.scatterplot(x='BMI', y='Outcome', data=df)

# %% [markdown]
# <strong>BMI is equally distributed between 22 to 48. BMI greater than 50 has a higher chance of daibetes. BMI less than 22 has lower chance of diabtes.</strong>

# %%
sns.scatterplot(x='DiabetesPedigreeFunction', y='Outcome', data=df)

# %% [markdown]
# <strong>DiabtesPedigreeFunction is equally distributed between 0 to 1.25. High chance of diabetes between 1.25 to 1.5</strong>

# %%
sns.scatterplot(x='SkinThickness', y='Outcome', data=df)

# %% [markdown]
# <strong>Skin Thickness is normally dsitributed between range 5 to 55</strong>

# %%
sns.scatterplot(x='Age', y='Outcome', data=df)

# %% [markdown]
# <strong>Age is normally distributed between 20 to 65. Less chance of diabetes if age is above 65</strong>

# %% [markdown]
# <h2>Pairplot of All Functions</h2>

# %%
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# <strong>Correlation</strong>

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# <strong>Points from corrleation
#     <ul>
#         <li>Glucose has highest correlation with Outcome</li>
#         <li>Blood Pressure has lowest coorrelation</li>
#     </ul></strong>

# %% [markdown]
# <strong><h3>Sorted Correlation vlaues for outcome variable</h3></strong>

# %%
df.corr()['Outcome'].sort_values()
# Out:
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# DiabetesPedigreeFunction    0.173844
# Pregnancies                 0.221898
# Age                         0.238356
# BMI                         0.292695
# Glucose                     0.466581
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# <strong><h3>Correlation Using Heatmap</h3></strong>

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=0.5, linecolor='black',fmt='.2f')

# %% [markdown]
# <strong><h3>Outcome of Correlation Matrix</h3></strong>
# <ul>
#     <li>Preganacies have 22% correlation with the outcome. can be considered as a good bond</li>
#     <li>Glucose have 47% correlation with the outcome. can be considered as a good bond</li>
#     <li>Blood Pressure have 7% correlation with the outcome. can be considered as a weak bond</li>
#     <li>SkinThickness have 7% correlation with the outcome. can be considered as a weak bond</li>
#     <li>Insulin have 13% correlation with the outcome. can be considered as a good bond</li>
#     <li>BMI have 29% correlation with the outcome. can be considered as a good bond</li>
#     <li>DiabetesPedigreeFunction have 17% correlation with the outcome. can be considered as a good bond</li>
#     <li>Age have 24% correlation with the outcome. can be considered as a good bond</li>
#
# </ul>

# %% [markdown]
# <strong><h3>Descriptive Statistics</h3></strong>

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# <h3>Outcomes:
#         <ul>
#             <li>Skewness Present in Preganancies</li>
#             <li>Skewness also in glucose variable</li>
#             <li>Skewness also in BloodPressure</li>
#             <li>Skewness in SkinThickness</li>
#             <li>Skewness in insulin</li>
#             <li>BMI, DiabtesPedigreeFunction and Age also gave skewness</li>
#         </ul>
# </h3>

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidth=2, fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variable Summary')
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# <h3><strong>Outcome of Description Statistics</strong></h3>
#
# <ul>
#     <li><strong>Pregancies: Catregorical Variable</strong>
#         <ol>
#             <li>Min_value = 0.00</li>
#             <li>25% = 1.00</li>
#             <li>50% = 3.00</li>
#             <li>75%=6.00</li>
#             <li>Max_value = 17.00</li>
#         </ol>
#     </li>
#     <li><strong>Glucose</strong>
#         <ol>
#             <li>Mean = 120.89</li>
#             <li>STD = 31.79</li>
#             <li>Max_value = 0.00</li>
#             <li>Min_value = 199.00</li>
#         </ol>
#     </li>
#     <li><strong>BloodPressure</strong>
#         <ol>
#             <li>Mean = 69.11</li>
#             <li>STD = 19.36</li>
#             <li>Max_value = 122</li>
#             <li>Min_value = 0</li>
#         </ol>
#     </li>
#     <li><strong>Skin Thickness</strong>
#         <ol>
#             <li>Mean = 20.54</li>
#             <li>STD = 15.95</li>
#             <li>Max_value = 99.0</li>
#             <li>Min_value = 0.00</li>
#         </ol>
#     </li>
#     <li><strong>Insulin</strong>
#         <ol>
#             <li>Mean = 79.8</li>
#             <li>STD = 115.24</li>
#             <li>Max_value = 846.00</li>
#             <li>Min_value = 0.0</li>
#         </ol>
#     </li>
#     <li><strong>BMI</strong>
#         <ol>
#             <li>Mean = 31.99</li>
#             <li>STD = 7.88</li>
#             <li>Max_value = 67.1</li>
#             <li>Min_value = 0</li>
#         </ol>
#     </li>
#     <li><strong>DiabetesPedigreeFunction</strong>
#         <ol>
#             <li>Mean = 0.47 </li>
#             <li>STD = 0.33</li>
#             <li>Max_value = 2.42</li>
#             <li>Min_value = 0.08</li>
#         </ol>
#     </li>
#     <li><strong>Age : Categorical variable</strong>
#         <ol>
#             <li>Min = 21</li>
#             <li>25% = 24</li>
#             <li>50% = 29</li>
#             <li>75% = 41</li>
#             <li>Max = 81</li>
#         </ol>
#     </li>
# </ul>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# <h3>Handling Outliers</h3>

# %%
collist = df.columns.values
ncol = 30
nrows = 14
sns.set_theme(style="whitegrid")
plt.figure(figsize=(ncol, 3*ncol))
for i in range(0 , len(collist)):
    plt.subplot(nrows, ncol, i+1)
#     plt.xlabel(str(collist[i]))
    sns.boxplot(data=df[collist[i]], color='green', orient='v')
    
plt.tight_layout()

# %% [markdown]
# <strong>Pregancies, SkinThickness, Glucose has less outliers, while BloodPressure,Insulin, BMI, DiabeticPedigreeFunction , age has mnore outliers.Outcome has no outliers</strong>

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [markdown]
# <strong>Skewness Threshold +/- 0.65</strong>
# <strong>Cloumns which have skew
#     <ul>
#         <li>Pregancies</li>
#         <li>BloodPressure</li>
#         <li>Insulin</li>
#         <li>DiabeticPedigreeFunction</li>
#         <li>Age</li>
#     </ul>
# </strong>

# %%
sns.distplot(df['Pregnancies'])

# %% [markdown]
#  data is not normally distirbuted

# %%
sns.distplot(df['Glucose'])

# %% [markdown]
# Glucose is bimodal (one mode is at 0 another is at 110)

# %%
sns.distplot(df['BloodPressure'])

# %% [markdown]
# BloodPressure is bimodal (one mode is at 0 another is at 70)

# %%
sns.distplot(df['SkinThickness'])

# %% [markdown]
# SkinThickness is bimodal (one mode is at 0 another is at 30)

# %%
sns.distplot(df['Insulin'])

# %% [markdown]
# Insulin is not normally distributed

# %%
sns.distplot(df['BMI'])

# %% [markdown]
# BMI is bimoadal

# %%
sns.distplot(df['DiabetesPedigreeFunction'])

# %% [markdown]
# Not Normalised

# %%
sns.distplot(df['Age'])

# %% [markdown]
# Not normalised

# %% [markdown]
# <H3>the data is not normalised</H3>

# %%
df.corr()['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# We will delete SkinThickness and BloodPressure Column from our data as they have very less correlation and high number of outliers

# %%
delete = pd.DataFrame([['0.065068', 'BloodPressure', 'No', 'Alot'], ['0.074752', 'skinThickness', 'No', 'Alot']],
                     columns=['Correlation with outcome', 'ColumnName', 'Normalised','Outliers'])
delete
# Out:
#   Correlation with outcome     ColumnName Normalised Outliers
# 0                 0.065068  BloodPressure         No     Alot
# 1                 0.074752  skinThickness         No     Alot

# %%
df = df.drop(['BloodPressure', 'SkinThickness'], axis=1)
df
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 4              0      137      168  43.1                     2.288   33
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# ...

# %% [markdown]
# <h3>Removing Outliers</h3>

# %% [markdown]
# Using Z-score Technique

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
z.shape
# Out:
# (768, 7)

# %%
z = pd.DataFrame(z, columns=df.columns)
z
# Out:
#      Pregnancies   Glucose   Insulin       BMI  DiabetesPedigreeFunction  \
# 0       0.639947  0.848324  0.692891  0.204013                  0.468492
# 1       0.844885  1.123396  0.692891  0.684422                  0.365061
# 2       1.233880  1.943724  0.692891  1.103255                  0.604397
# 3       0.844885  0.998208  0.123302  0.494043                  0.920763
# 4       1.141852  0.504055  0.765836  1.409746                  5.484909
# ..           ...       ...       ...       ...                       ...
# 763     1.827813  0.622642  0.870031  0.115169                  0.908682
# 764     0.547919  0.034598  0.692891  0.610154                  0.398282
# 765     0.342981  0.003301  0.279594  0.735190                  0.685193
# 766     0.844885  0.159787  0.692891  0.240205                  0.371101
# 767     0.844885  0.873019  0.692891  0.202129                  0.473785
#
#           Age   Outcome
# 0    1.425995  1.365896
# 1    0.190672  0.732120
# ...

# %% [markdown]
# Any value above 3 in z-score table is considered an outlier

# %%
print(np.where(z>3))
# Out:
# (array([  4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
#        145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
#        342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
#        455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
#        684, 684, 695, 706, 753], dtype=int64), array([4, 2, 3, 2, 4, 3, 4, 3, 1, 3, 0, 2, 5, 3, 2, 0, 3, 1, 2, 2, 2, 4,
#        2, 2, 0, 4, 1, 1, 2, 4, 3, 4, 4, 2, 2, 3, 3, 4, 5, 0, 5, 2, 3, 1,
#        3, 2, 4, 4, 2, 2, 5, 3, 3, 5, 2, 3, 2], dtype=int64))

# %%
df_new = df[(z<3).all(axis=1)]
print("Old Shape", df.shape)
print("New Shape", df_new.shape)
print("Total Dropped Rows", df.shape[0] - df_new.shape[0])
# Out:
# Old Shape (768, 7)
# New Shape (716, 7)
# Total Dropped Rows 52

# %%
df_new
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 5              5      116        0  25.6                     0.201   30
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 5          0
# ..       ...
# ...

# %%
from sklearn.preprocessing import power_transform
x = df_new.iloc[:,:-1]
y = df_new.iloc[:,-1]

# %% [markdown]
# <h4>Trnasformation to remove skewness</h4>

# %%
x = power_transform(x, method='yeo-johnson')
x
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.16989991,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %%
x_df = pd.DataFrame(x, columns=df_new.columns[:-1])
x_df.skew()
# Out:
# Pregnancies                -0.049433
# Glucose                    -0.000674
# Insulin                     0.048410
# BMI                        -0.005045
# DiabetesPedigreeFunction    0.128437
# Age                         0.142388
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.16989991,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %%
x_df = pd.DataFrame(x, columns=df_new.columns[:-1])
x_df.mean()
# Out:
# Pregnancies                -4.961891e-18
# Glucose                     1.891721e-17
# Insulin                     4.527725e-17
# BMI                        -3.236858e-17
# DiabetesPedigreeFunction    2.604993e-17
# Age                         2.015768e-17
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h3>Making predictions</h3>

# %%
for i in range(0,1000):
    x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=i, test_size=0.20)
    lr.fit(x_train, y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(accuracy_score(y_train, pred_train)*100, 1) == round(accuracy_score(y_test, pred_test)*100,1):
        print("At random state", i, "The model performs very well")
        print("At random state", i , ":")
        print("Training Accuracy is :" ,round(accuracy_score(y_train, pred_train)*100, 1))
        print("Testing Accuracy is :" ,round(accuracy_score(y_test, pred_test)*100, 1))
# Out:
# At random state 51 The model performs very well
# At random state 51 :
# Training Accuracy is : 77.8
# Testing Accuracy is : 77.8
# At random state 86 The model performs very well
# At random state 86 :
# Training Accuracy is : 77.8
# Testing Accuracy is : 77.8
# At random state 90 The model performs very well
# At random state 90 :
# Training Accuracy is : 78.5
# Testing Accuracy is : 78.5
# At random state 93 The model performs very well
# At random state 93 :
# Training Accuracy is : 77.8
# Testing Accuracy is : 77.8
# At random state 127 The model performs very well
# At random state 127 :
# Training Accuracy is : 78.5
# Testing Accuracy is : 78.5
# At random state 135 The model performs very well
# At random state 135 :
# Training Accuracy is : 77.8
# Testing Accuracy is : 77.8
# At random state 185 The model performs very well
# At random state 185 :
# Training Accuracy is : 78.5
# Testing Accuracy is : 78.5
# At random state 205 The model performs very well
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=986)

# %%
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       101
#            1       0.63      0.60      0.62        43
#
#     accuracy                           0.78       144
#    macro avg       0.73      0.73      0.73       144
# weighted avg       0.77      0.78      0.78       144

# %%
lss = accuracy_score(y_test, y_pred)
lss
# Out:
# 0.7777777777777778

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    lssscore = cross_val_score(lr,x,y, cv=j)
    lsc =lssscore.mean()
    print("At CV :", j)
    print("Cross Validation score is : -", lsc*100)
    print("Accuracy sicre is : -", lss*100)
# Out:
# At CV : 2
# Cross Validation score is : - 77.6536312849162
# Accuracy sicre is : - 77.77777777777779
# At CV : 3
# Cross Validation score is : - 77.3777293344116
# Accuracy sicre is : - 77.77777777777779
# At CV : 4
# Cross Validation score is : - 77.09497206703911
# Accuracy sicre is : - 77.77777777777779
# At CV : 5
# Cross Validation score is : - 77.09693084693085
# Accuracy sicre is : - 77.77777777777779
# At CV : 6
# Cross Validation score is : - 77.37745098039215
# Accuracy sicre is : - 77.77777777777779
# At CV : 7
# Cross Validation score is : - 77.09880068532267
# Accuracy sicre is : - 77.77777777777779
# At CV : 8
# Cross Validation score is : - 77.2456304619226
# Accuracy sicre is : - 77.77777777777779
# At CV : 9
# Cross Validation score is : - 77.52461322081574
# Accuracy sicre is : - 77.77777777777779

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_pred, y_test)
roc_auc = auc(fpr,tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=10, label='ROC Curve (area=0.2%f)' %roc_auc)
plt.plot([0,1], [0,1], color='navy',lw=10, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.title('Reciever Operating Characteristics')
plt.legend(loc='lower right')
plt.show()
